# %%
import pandas as pd
import numpy as np

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
from nltk.corpus import stopwords
import collections
import liwc
from collections import Counter

# %%
df = []

# %%
data_files = ['schizophrenia.csv','fitness.csv','jokes.csv','meditation.csv','parenting.csv','relationships.csv','teaching.csv']
for file in data_files:
    data = pd.read_csv(file)
    df.append(data)
df = pd.concat(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4227 entries, 0 to 552
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      4227 non-null   int64
#  1   Title           4227 non-null   object
#  2   Post Text       4018 non-null   object
#  3   ID              4227 non-null   object
#  4   Score           4227 non-null   int64
#  5   Total Comments  4227 non-null   int64
#  6   Post URL        4227 non-null   object
#  7   Label           4227 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 297.2+ KB

# %%
df = df.dropna()

# %%
df['message'] = df['Post Text']

# %%
import seaborn as sns
sns.countplot(x="Label", data = df)
# Out:
# <AxesSubplot:xlabel='Label', ylabel='count'>

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# %%
comment_words = ''
stopwords = set(STOPWORDS)

# %%
for val in df.message:
     
    # typecaste each val to string
    val = str(val)
 
    # split the value
    tokens = val.split()
     
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
     
    comment_words += " ".join(tokens)+" "

# %%
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)

# %%
# plot the WordCloud image                      
plt.figure(figsize = (12, 12), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %%
X = df['message']
y = df['Label']

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split

cv = CountVectorizer()
X = cv.fit_transform(X) # Fit the Data

# %%
parse, category_names = liwc.load_token_parser('LIWC2007_English100131.dic')

# %%
#LIWC Features Extraction
liwc =[] 
for item in df.message:
    gettysburg_counts = list(collections.Counter(category for message in item for category in parse(message) if category == 'schizophrenia').items())
    liwc.append(gettysburg_counts)
liwc_ = np.array(liwc)

# %% [markdown]
# # Machine Learning

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import warnings

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
RandomForest = RandomForestClassifier(n_estimators=10, random_state=0)
RandomForest.fit(X, y) 
y_pred = RandomForest.predict(X)
print(confusion_matrix(y,y_pred))
print(classification_report(y,y_pred))
print(accuracy_score(y, y_pred))
RF = accuracy_score(y, y_pred)
# Out:
# [[ 30   0   0   0   0   0   0]
#  [  0 738   0   0   0   2   0]
#  [  0   1 730   0   0   2   0]
#  [  0   0   1 860   1   0   0]
#  [  0   0   0   0 408   0   0]
#  [  0   1   6   2   0 723   0]
#  [  0   1   0   2   0   0 510]]
#                precision    recall  f1-score   support
#
#       fitness       1.00      1.00      1.00        30
#         jokes       1.00      1.00      1.00       740
#    meditation       0.99      1.00      0.99       733
#     parenting       1.00      1.00      1.00       862
# relationships       1.00      1.00      1.00       408
# schizophrenia       0.99      0.99      0.99       732
#      teaching       1.00      0.99      1.00       513
#
#      accuracy                           1.00      4018
#     macro avg       1.00      1.00      1.00      4018
#  weighted avg       1.00      1.00      1.00      4018
#
# 0.9952712792434046

# %% [markdown]
# # Support Vector Machine

# %%
from sklearn.svm import SVC
clf = SVC(gamma='auto')
clf.fit(X, y) 
y_pred = clf.predict(X)
print(confusion_matrix(y,y_pred))
print(classification_report(y,y_pred))
print(accuracy_score(y, y_pred))
SVM = accuracy_score(y, y_pred)
# Out:
# [[  1   8  20   0   0   1   0]
#  [  0 698   6  36   0   0   0]
#  [  0 389 314  10   2  18   0]
#  [  0 276  83 428  22  53   0]
#  [  0   3  14 108 244  39   0]
#  [  0 397 110  34  10 181   0]
#  [  0 234 135  57   5  42  40]]
#                precision    recall  f1-score   support
#
#       fitness       1.00      0.03      0.06        30
#         jokes       0.35      0.94      0.51       740
#    meditation       0.46      0.43      0.44       733
#     parenting       0.64      0.50      0.56       862
# relationships       0.86      0.60      0.71       408
# schizophrenia       0.54      0.25      0.34       732
#      teaching       1.00      0.08      0.14       513
#
#      accuracy                           0.47      4018
#     macro avg       0.69      0.40      0.40      4018
#  weighted avg       0.61      0.47      0.45      4018
#
# 0.47436535589845696

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression()
clf.fit(X, y) 
y_pred = clf.predict(X)
print(confusion_matrix(y,y_pred))
print(classification_report(y,y_pred))
print(accuracy_score(y, y_pred))
LR = accuracy_score(y, y_pred)
# Out:
# [[ 30   0   0   0   0   0   0]
#  [  0 740   0   0   0   0   0]
#  [  0  15 718   0   0   0   0]
#  [  0   0   0 862   0   0   0]
#  [  0   0   0   0 408   0   0]
#  [  0  10   0   0   0 722   0]
#  [  0   8   0   0   0   0 505]]
#                precision    recall  f1-score   support
#
#       fitness       1.00      1.00      1.00        30
#         jokes       0.96      1.00      0.98       740
#    meditation       1.00      0.98      0.99       733
#     parenting       1.00      1.00      1.00       862
# relationships       1.00      1.00      1.00       408
# schizophrenia       1.00      0.99      0.99       732
#      teaching       1.00      0.98      0.99       513
#
#      accuracy                           0.99      4018
#     macro avg       0.99      0.99      0.99      4018
#  weighted avg       0.99      0.99      0.99      4018
#
# 0.9917869586859134
# C:\Users\Public\anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB
clf = MultinomialNB()
clf.fit(X, y) 
y_pred = clf.predict(X)
print(confusion_matrix(y,y_pred))
print(classification_report(y,y_pred))
print(accuracy_score(y, y_pred))
NB = accuracy_score(y, y_pred)
# Out:
# [[ 28   0   0   0   0   0   2]
#  [  0 471  29 116  52  52  20]
#  [  2   7 691   9  10  12   2]
#  [  1   1   4 837  10   3   6]
#  [  0   0   0   2 406   0   0]
#  [  2   3  17  22  24 658   6]
#  [  0   2   4  21   3   7 476]]
#                precision    recall  f1-score   support
#
#       fitness       0.85      0.93      0.89        30
#         jokes       0.97      0.64      0.77       740
#    meditation       0.93      0.94      0.94       733
#     parenting       0.83      0.97      0.90       862
# relationships       0.80      1.00      0.89       408
# schizophrenia       0.90      0.90      0.90       732
#      teaching       0.93      0.93      0.93       513
#
#      accuracy                           0.89      4018
#     macro avg       0.89      0.90      0.89      4018
#  weighted avg       0.90      0.89      0.88      4018
#
# 0.8877551020408163

# %% [markdown]
# # Voting Classifier

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.neural_network import MLPClassifier
from sklearn import model_selection
from sklearn.svm import SVC

estimators = []
model1 = LogisticRegression()
estimators.append(('logistic', model1))
model2 = RandomForestClassifier()
estimators.append(('cart', model2))
model3 = SVC()
estimators.append(('svm', model3))

# create the ensemble model
ensemble = VotingClassifier(estimators)
warnings.simplefilter("ignore")

print(ensemble)
ensemble.fit(X, y)

y_pred = ensemble.predict(X)
print(confusion_matrix(y,y_pred))
print(classification_report(y,y_pred))
print(accuracy_score(y, y_pred))

E= accuracy_score(y, y_pred)
# Out:
# VotingClassifier(estimators=[('logistic', LogisticRegression()),
#                              ('cart', RandomForestClassifier()),
#                              ('svm', SVC())])
# [[ 30   0   0   0   0   0   0]
#  [  0 740   0   0   0   0   0]
#  [  0  15 718   0   0   0   0]
#  [  0   0   0 862   0   0   0]
#  [  0   0   0   0 408   0   0]
#  [  0  10   0   0   0 722   0]
#  [  0   8   0   0   0   0 505]]
#                precision    recall  f1-score   support
#
#       fitness       1.00      1.00      1.00        30
#         jokes       0.96      1.00      0.98       740
#    meditation       1.00      0.98      0.99       733
#     parenting       1.00      1.00      1.00       862
# relationships       1.00      1.00      1.00       408
# schizophrenia       1.00      0.99      0.99       732
#      teaching       1.00      0.98      0.99       513
#
#      accuracy                           0.99      4018
#     macro avg       0.99      0.99      0.99      4018
#  weighted avg       0.99      0.99      0.99      4018
#
# 0.9917869586859134

# %% [markdown]
# # Stacking Classifier

# %%
from sklearn.ensemble import StackingClassifier
from catboost import CatBoostClassifier
from sklearn.ensemble import AdaBoostClassifier

estimators = [('AdaBoost', AdaBoostClassifier(n_estimators=100, random_state=0)),
              ('CatBoost',CatBoostClassifier(verbose=0, n_estimators=100))]
clf = StackingClassifier(estimators=estimators, final_estimator=LogisticRegression())

# %%
clf.fit(X, y) 
y_pred = clf.predict(X)
print(confusion_matrix(y,y_pred))
print(classification_report(y,y_pred))
print(accuracy_score(y, y_pred))
Stack = accuracy_score(y, y_pred)
# Out:
# [[ 25   2   0   0   0   3   0]
#  [  0 697   9  12   0  20   2]
#  [  0  50 627  13   0  39   4]
#  [  0  21   5 802   3  21  10]
#  [  0   0   0   5 402   1   0]
#  [  0  58  21  13   0 637   3]
#  [  0  25   7  25   0  21 435]]
#                precision    recall  f1-score   support
#
#       fitness       1.00      0.83      0.91        30
#         jokes       0.82      0.94      0.88       740
#    meditation       0.94      0.86      0.89       733
#     parenting       0.92      0.93      0.93       862
# relationships       0.99      0.99      0.99       408
# schizophrenia       0.86      0.87      0.86       732
#      teaching       0.96      0.85      0.90       513
#
#      accuracy                           0.90      4018
#     macro avg       0.93      0.89      0.91      4018
#  weighted avg       0.91      0.90      0.90      4018
#
# 0.9021901443504231

# %% [markdown]
# # Deep Learning

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import layers, callbacks
from tensorflow.keras import Model, Sequential

from nltk.stem import SnowballStemmer
from nltk.corpus import stopwords
import re
import string

# %%
# Encoded Sentiment columns

from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df['Label'] = encoder.fit_transform(df['Label'])

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Tru
# [nltk_data]     Projects\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
num_classes = df.Label.nunique()
print(num_classes)
# Out:
# 7

# %%
def cleaning_text(text):
    stop_words = stopwords.words("english")

    text = re.sub(r'http\S+', " ", text)    # remove urls
    text = re.sub(r'@\w+',' ',text)         # remove mentions
    text = re.sub(r'#\w+', ' ', text)       # remove hastags
    text = re.sub('r<.*?>',' ', text)       # remove html tags
    
    # remove stopwords 
    text = text.split()
    text = " ".join([word for word in text if not word in stop_words])

    for punctuation in string.punctuation:
        text = text.replace(punctuation, "")
    
    return text

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4018 entries, 0 to 552
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      4018 non-null   int64
#  1   Title           4018 non-null   object
#  2   Post Text       4018 non-null   object
#  3   ID              4018 non-null   object
#  4   Score           4018 non-null   int64
#  5   Total Comments  4018 non-null   int64
#  6   Post URL        4018 non-null   object
#  7   Label           4018 non-null   int64
#  8   message         4018 non-null   object
#  9   text            4018 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 474.3+ KB

# %%
df['text'] = df['text'].apply(lambda x: cleaning_text(x))

# %%
# Maximum sentence length
max_len_words = max(list(df['text'].apply(len)))
print(max_len_words)
# Out:
# 10841

# %%
def tokenizer(x_train, y_train, max_len_word):
    # because the data distribution is imbalanced, "stratify" is used
    X_train, X_val, y_train, y_val = train_test_split(x_train, y_train, 
                                                      test_size=.2, shuffle=True, 
                                                      stratify=y_train, random_state=0)

    # Tokenizer
    tokenizer = Tokenizer(num_words=5000)
    tokenizer.fit_on_texts(X_train)
    sequence_dict = tokenizer.word_index
    word_dict = dict((num, val) for (val, num) in sequence_dict.items())

    # Sequence data
    train_sequences = tokenizer.texts_to_sequences(X_train)
    train_padded = pad_sequences(train_sequences,
                                 maxlen=max_len_word,
                                 truncating='post',
                                 padding='post')
    
    val_sequences = tokenizer.texts_to_sequences(X_val)
    val_padded = pad_sequences(val_sequences,
                                maxlen=max_len_word,
                                truncating='post',
                                padding='post', )
    
    print(train_padded.shape)
    print(val_padded.shape)
    print('Total words: {}'.format(len(word_dict)))
    return train_padded, val_padded, y_train, y_val, word_dict

X_train, X_val, y_train, y_val, word_dict = tokenizer(df.text, df.Label, 100)
# Out:
# (3214, 100)
# (804, 100)
# Total words: 20040

# %% [markdown]
# # DNN

# %%
import tensorflow as tf
model = Sequential([
    layers.Embedding(5000, 100, input_length=100),
    layers.SimpleRNN(64, return_sequences=True, recurrent_dropout=0.4),
    layers.GlobalAveragePooling1D(),    # or layers.Flatten()
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.4),
    layers.Dense(num_classes, activation='softmax')
])

# %%
model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              metrics=['accuracy'])

# %%
trained = model.fit(X_train, y_train,
                    epochs=10, 
                    validation_data=(X_val, y_val),
                    shuffle=True)
# Out:
# Epoch 1/10
# 101/101 [==============================] - 5s 47ms/step - loss: 1.8030 - accuracy: 0.2380 - val_loss: 1.7198 - val_accuracy: 0.2948
# Epoch 2/10
# 101/101 [==============================] - 3s 30ms/step - loss: 1.6221 - accuracy: 0.3220 - val_loss: 1.7352 - val_accuracy: 0.3109
# Epoch 3/10
# 101/101 [==============================] - 3s 30ms/step - loss: 1.5745 - accuracy: 0.3391 - val_loss: 1.7390 - val_accuracy: 0.3047
# Epoch 4/10
# 101/101 [==============================] - 3s 30ms/step - loss: 1.5446 - accuracy: 0.3494 - val_loss: 1.9750 - val_accuracy: 0.3271
# Epoch 5/10
# 101/101 [==============================] - 3s 30ms/step - loss: 1.4981 - accuracy: 0.3703 - val_loss: 2.1528 - val_accuracy: 0.3209
# Epoch 6/10
# 101/101 [==============================] - 3s 29ms/step - loss: 1.4494 - accuracy: 0.3864 - val_loss: 2.3949 - val_accuracy: 0.3246
# Epoch 7/10
# 101/101 [==============================] - 3s 30ms/step - loss: 1.3960 - accuracy: 0.4020 - val_loss: 1.9546 - val_accuracy: 0.3682
# Epoch 8/10
# 101/101 [==============================] - 3s 30ms/step - loss: 1.3458 - accuracy: 0.4284 - val_loss: 1.9167 - val_accuracy: 0.3769
# Epoch 9/10
# 101/101 [==============================] - 3s 30ms/step - loss: 1.2930 - accuracy: 0.4521 - val_loss: 1.8164 - val_accuracy: 0.3731
# Epoch 10/10
# 101/101 [==============================] - 3s 30ms/step - loss: 1.2502 - accuracy: 0.4636 - val_loss: 2.2487 - val_accuracy: 0.3532

# %%
plt.plot(trained.history['accuracy'])
plt.plot(trained.history['val_accuracy'])
plt.title('Accuracy Curves')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
plt.plot(trained.history['loss'])
plt.plot(trained.history['val_loss'])
plt.title('Loss Curves')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
rnn = trained.history['val_accuracy']

# %% [markdown]
# # CNN

# %%
from keras.layers import Embedding, Conv1D, MaxPooling1D, Flatten, Dense
from tensorflow.keras.optimizers import Adam, SGD
def build_cnn_model():
    model = Sequential()
    
    model.add(Embedding(5000, 100, input_length=100))


    model.add(Conv1D(64, 2, padding='same', activation='relu'))
    model.add(MaxPooling1D(2))
    #model.add(MaxPooling1D(2))
    
    model.add(Flatten())
    
    model.add(Dense(units=1024,activation="relu"))
    model.add(Dense(units=512,activation="relu"))
    
    model.add(Dense(units=num_classes,activation="softmax"))
    
    optimizer = Adam(lr=0.000055,beta_1=0.9,beta_2=0.999)
    
    model.compile(optimizer=optimizer,metrics=["accuracy"],loss=tf.keras.losses.SparseCategoricalCrossentropy())
    return model

# %%
cnn_model = build_cnn_model()
cnn_history = cnn_model.fit(X_train, y_train,
                    epochs=10, 
                    validation_data=(X_val, y_val),
                    shuffle=True)
# Out:
# Epoch 1/10
# 101/101 [==============================] - 3s 30ms/step - loss: 1.6949 - accuracy: 0.3283 - val_loss: 1.5412 - val_accuracy: 0.3619
# Epoch 2/10
# 101/101 [==============================] - 3s 28ms/step - loss: 1.4826 - accuracy: 0.3914 - val_loss: 1.4772 - val_accuracy: 0.3644
# Epoch 3/10
# 101/101 [==============================] - 3s 30ms/step - loss: 1.4072 - accuracy: 0.4266 - val_loss: 1.4343 - val_accuracy: 0.3993
# Epoch 4/10
# 101/101 [==============================] - 3s 29ms/step - loss: 1.3035 - accuracy: 0.5162 - val_loss: 1.3051 - val_accuracy: 0.5012
# Epoch 5/10
# 101/101 [==============================] - 3s 27ms/step - loss: 1.1109 - accuracy: 0.6164 - val_loss: 1.1674 - val_accuracy: 0.5386
# Epoch 6/10
# 101/101 [==============================] - 3s 28ms/step - loss: 0.9186 - accuracy: 0.6973 - val_loss: 1.0324 - val_accuracy: 0.6393
# Epoch 7/10
# 101/101 [==============================] - 3s 28ms/step - loss: 0.7337 - accuracy: 0.7959 - val_loss: 0.9012 - val_accuracy: 0.7177
# Epoch 8/10
# 101/101 [==============================] - 3s 27ms/step - loss: 0.5556 - accuracy: 0.8525 - val_loss: 0.8120 - val_accuracy: 0.7164
# Epoch 9/10
# 101/101 [==============================] - 3s 27ms/step - loss: 0.4081 - accuracy: 0.9023 - val_loss: 0.7152 - val_accuracy: 0.7674
# Epoch 10/10
# 101/101 [==============================] - 3s 29ms/step - loss: 0.3100 - accuracy: 0.9278 - val_loss: 0.6658 - val_accuracy: 0.7873

# %%
cnn = cnn_history.history['val_accuracy']

# %%
plt.plot(cnn_history.history['accuracy'])
plt.plot(cnn_history.history['val_accuracy'])
plt.title('Accuracy Curves')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
plt.plot(cnn_history.history['loss'])
plt.plot(cnn_history.history['val_loss'])
plt.title('Loss Curves')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# # GNN - GRU

# %%
import tensorflow as tf
model = Sequential([
    layers.Embedding(5000, 100, input_length=100),
    layers.GRU(64, return_sequences=True, recurrent_dropout=0.4),
    layers.GlobalAveragePooling1D(),    # or layers.Flatten()
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.4),
    layers.Dense(num_classes, activation='softmax')
])

# %%
model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              metrics=['accuracy'])

# %%
trained = model.fit(X_train, y_train,
                    epochs=10, 
                    validation_data=(X_val, y_val),
                    shuffle=True)
# Out:
# Epoch 1/10
# 101/101 [==============================] - 6s 62ms/step - loss: 1.6737 - accuracy: 0.3006 - val_loss: 1.3848 - val_accuracy: 0.4080
# Epoch 2/10
# 101/101 [==============================] - 6s 57ms/step - loss: 1.2749 - accuracy: 0.4431 - val_loss: 1.1201 - val_accuracy: 0.5435
# Epoch 3/10
# 101/101 [==============================] - 6s 58ms/step - loss: 0.8256 - accuracy: 0.6677 - val_loss: 0.6844 - val_accuracy: 0.7575
# Epoch 4/10
# 101/101 [==============================] - 6s 57ms/step - loss: 0.4267 - accuracy: 0.8696 - val_loss: 0.5795 - val_accuracy: 0.8221
# Epoch 5/10
# 101/101 [==============================] - 6s 58ms/step - loss: 0.2446 - accuracy: 0.9381 - val_loss: 0.5683 - val_accuracy: 0.8358
# Epoch 6/10
# 101/101 [==============================] - 6s 60ms/step - loss: 0.1754 - accuracy: 0.9568 - val_loss: 0.6053 - val_accuracy: 0.8433
# Epoch 7/10
# 101/101 [==============================] - 6s 59ms/step - loss: 0.1362 - accuracy: 0.9648 - val_loss: 0.7116 - val_accuracy: 0.8209
# Epoch 8/10
# 101/101 [==============================] - 6s 58ms/step - loss: 0.0924 - accuracy: 0.9782 - val_loss: 0.7597 - val_accuracy: 0.8333
# Epoch 9/10
# 101/101 [==============================] - 6s 58ms/step - loss: 0.0846 - accuracy: 0.9813 - val_loss: 0.8110 - val_accuracy: 0.8134
# Epoch 10/10
# 101/101 [==============================] - 6s 58ms/step - loss: 0.0695 - accuracy: 0.9851 - val_loss: 0.7389 - val_accuracy: 0.8333

# %%
gru = trained.history['val_accuracy']

# %%
plt.plot(trained.history['accuracy'])
plt.plot(trained.history['val_accuracy'])
plt.title('Accuracy Curves')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
plt.plot(trained.history['loss'])
plt.plot(trained.history['val_loss'])
plt.title('Loss Curves')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# # LSTM

# %%
import tensorflow as tf
model = Sequential([
    layers.Embedding(5000, 100, input_length=100),
    layers.LSTM(64, return_sequences=True, recurrent_dropout=0.4),
    layers.GlobalAveragePooling1D(),    # or layers.Flatten()
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.4),
    layers.Dense(num_classes, activation='softmax')
])

# %%
model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              metrics=['accuracy'])

# %%
trained = model.fit(X_train, y_train,
                    epochs=10, 
                    validation_data=(X_val, y_val),
                    shuffle=True)
# Out:
# Epoch 1/10
# 101/101 [==============================] - 7s 70ms/step - loss: 1.6651 - accuracy: 0.3040 - val_loss: 1.4202 - val_accuracy: 0.3818
# Epoch 2/10
# 101/101 [==============================] - 7s 65ms/step - loss: 1.3254 - accuracy: 0.4300 - val_loss: 1.2202 - val_accuracy: 0.5236
# Epoch 3/10
# 101/101 [==============================] - 7s 65ms/step - loss: 1.0314 - accuracy: 0.5675 - val_loss: 0.9742 - val_accuracy: 0.6269
# Epoch 4/10
# 101/101 [==============================] - 7s 70ms/step - loss: 0.8898 - accuracy: 0.6441 - val_loss: 1.0632 - val_accuracy: 0.6368
# Epoch 5/10
# 101/101 [==============================] - 7s 68ms/step - loss: 0.7152 - accuracy: 0.7284 - val_loss: 0.9290 - val_accuracy: 0.6642
# Epoch 6/10
# 101/101 [==============================] - 7s 65ms/step - loss: 0.6109 - accuracy: 0.7918 - val_loss: 1.0222 - val_accuracy: 0.7214
# Epoch 7/10
# 101/101 [==============================] - 7s 65ms/step - loss: 0.6852 - accuracy: 0.7943 - val_loss: 0.9192 - val_accuracy: 0.6853
# Epoch 8/10
# 101/101 [==============================] - 7s 66ms/step - loss: 0.6159 - accuracy: 0.7847 - val_loss: 0.8633 - val_accuracy: 0.7015
# Epoch 9/10
# 101/101 [==============================] - 7s 66ms/step - loss: 0.5088 - accuracy: 0.7993 - val_loss: 0.7861 - val_accuracy: 0.7450
# Epoch 10/10
# 101/101 [==============================] - 7s 65ms/step - loss: 0.4429 - accuracy: 0.8479 - val_loss: 0.9363 - val_accuracy: 0.7736

# %%
lstm = trained.history['val_accuracy']

# %%
plt.plot(trained.history['accuracy'])
plt.plot(trained.history['val_accuracy'])
plt.title('Accuracy Curves')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
plt.plot(trained.history['loss'])
plt.plot(trained.history['val_loss'])
plt.title('Loss Curves')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# # CNN + LSTM

# %%
model = Sequential()
model.add(Embedding(5000, 100, input_length=100))
model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(LSTM(100))
model.add(Dense(num_classes, activation='sigmoid'))
model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(), optimizer='adam', metrics=['accuracy'])
print(model.summary())
filepath="weights_best_cnn.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max',save_weights_only=True)
callbacks_list = [checkpoint]
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_13 (Embedding)     (None, 100, 100)          500000
# _________________________________________________________________
# conv1d_9 (Conv1D)            (None, 100, 32)           9632
# _________________________________________________________________
# max_pooling1d_9 (MaxPooling1 (None, 50, 32)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100)               53200
# _________________________________________________________________
# dense_30 (Dense)             (None, 7)                 707
# =================================================================
# Total params: 563,539
# Trainable params: 563,539
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
trained = model.fit(X_train, y_train,
                    epochs=10, 
                    validation_data=(X_val, y_val),
                    shuffle=True)
# Out:
# Epoch 1/10
# 101/101 [==============================] - 4s 35ms/step - loss: 1.6522 - accuracy: 0.3099 - val_loss: 1.4955 - val_accuracy: 0.3619
# Epoch 2/10
# 101/101 [==============================] - 3s 31ms/step - loss: 1.3884 - accuracy: 0.4166 - val_loss: 1.3175 - val_accuracy: 0.4366
# Epoch 3/10
# 101/101 [==============================] - 3s 31ms/step - loss: 1.2349 - accuracy: 0.4910 - val_loss: 1.2194 - val_accuracy: 0.5075
# Epoch 4/10
# 101/101 [==============================] - 3s 31ms/step - loss: 1.0669 - accuracy: 0.5619 - val_loss: 1.1653 - val_accuracy: 0.5361
# Epoch 5/10
# 101/101 [==============================] - 3s 31ms/step - loss: 0.8940 - accuracy: 0.6288 - val_loss: 1.0787 - val_accuracy: 0.5746
# Epoch 6/10
# 101/101 [==============================] - 3s 31ms/step - loss: 0.7725 - accuracy: 0.6829 - val_loss: 1.2227 - val_accuracy: 0.5224
# Epoch 7/10
# 101/101 [==============================] - 3s 30ms/step - loss: 0.7276 - accuracy: 0.7175 - val_loss: 1.1766 - val_accuracy: 0.5572
# Epoch 8/10
# 101/101 [==============================] - 3s 31ms/step - loss: 0.7431 - accuracy: 0.6991 - val_loss: 1.1585 - val_accuracy: 0.5448
# Epoch 9/10
# 101/101 [==============================] - 3s 31ms/step - loss: 0.6464 - accuracy: 0.7393 - val_loss: 1.1422 - val_accuracy: 0.5896
# Epoch 10/10
# 101/101 [==============================] - 3s 31ms/step - loss: 0.5450 - accuracy: 0.7903 - val_loss: 1.2491 - val_accuracy: 0.6206

# %%
ense = trained.history['val_accuracy']

# %%
plt.plot(trained.history['accuracy'])
plt.plot(trained.history['val_accuracy'])
plt.title('Accuracy Curves')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
plt.plot(trained.history['loss'])
plt.plot(trained.history['val_loss'])
plt.title('Loss Curves')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
accuracies = [RF, SVM, LR, NB,E,Stack,rnn[9],cnn[9],gru[9],lstm[9],ense[9]]

# %%
for i in range(0, len(accuracies)):
    accuracies[i] = accuracies[i]*100
    print(accuracies[i])
# Out:
# 99.52712792434046
# 47.4365355898457
# 99.17869586859133
# 88.77551020408163
# 99.17869586859133
# 90.21901443504231
# 35.323384404182434
# 78.7313461303711
# 83.33333134651184
# 77.36318111419678
# 62.064677476882935

# %%
models = ['Random Forest', 'SVM', 'Logistic Regression','MNB','Voting Classifier','Stacking Boosting','DNN','CNN','GNN','LSTM','CNN+LSTM']

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(models,accuracies)
plt.xlabel("For First Dataset")
plt.ylabel("Accuracy (in %)")
plt.show()

# %%
import joblib
filename = 'model.sav'
joblib.dump(RandomForest, filename)
# Out:
# ['model.sav']
